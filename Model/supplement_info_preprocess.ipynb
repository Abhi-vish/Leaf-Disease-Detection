# %% [markdown]
# ## Preporcessing the dataset
#
# * "In the dataset, there was a record that we do not require for this task, which is why we are removing it."

# %% [markdown]
# ### Loading required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading the dataset

# %%
supplement_info = pd.read_csv('/content/supplement_info.csv',encoding='cp1252')
supplement_info.head()
# Out:
#    index               disease_name  \
# 0      0         Apple___Apple_scab
# 1      1          Apple___Black_rot
# 2      2   Apple___Cedar_apple_rust
# 3      3            Apple___healthy
# 4      4  Background_without_leaves
#
#                                      supplement name  \
# 0  Katyayani Prozol Propiconazole 25% EC Systemat...
# 1                    Magic FungiX For Fungal disease
# 2               Katyayani All in 1 Organic Fungicide
# 3                   Tapti Booster Organic Fertilizer
# 4                                                NaN
#
#                                     supplement image  \
# 0  https://encrypted-tbn1.gstatic.com/shopping?q=...
# 1  https://encrypted-tbn3.gstatic.com/shopping?q=...
# 2  https://encrypted-tbn2.gstatic.com/shopping?q=...
# 3  https://rukminim1.flixcart.com/image/416/416/k...
# 4                                                NaN
#
#                                             buy link
# ...

# %% [markdown]
# ### Removing the record

# %%
supplement_info = supplement_info.drop(supplement_info[supplement_info['index'] == 4].index)

# %%
supplement_info.head()
# Out:
#    index              disease_name  \
# 0      0        Apple___Apple_scab
# 1      1         Apple___Black_rot
# 2      2  Apple___Cedar_apple_rust
# 3      3           Apple___healthy
# 5      5       Blueberry___healthy
#
#                                      supplement name  \
# 0  Katyayani Prozol Propiconazole 25% EC Systemat...
# 1                    Magic FungiX For Fungal disease
# 2               Katyayani All in 1 Organic Fungicide
# 3                   Tapti Booster Organic Fertilizer
# 5                               GreenStix Fertilizer
#
#                                     supplement image  \
# 0  https://encrypted-tbn1.gstatic.com/shopping?q=...
# 1  https://encrypted-tbn3.gstatic.com/shopping?q=...
# 2  https://encrypted-tbn2.gstatic.com/shopping?q=...
# 3  https://rukminim1.flixcart.com/image/416/416/k...
# 5  https://encrypted-tbn3.gstatic.com/shopping?q=...
#
#                                             buy link
# ...

# %% [markdown]
# ### Removing the index column and adding the modified index column

# %%
supplement_info.drop(columns='index',inplace=True)

# %%
supplement_info['index'] = range(len(supplement_info))

# %%
supplement_info.head()
# Out:
#                disease_name  \
# 0        Apple___Apple_scab
# 1         Apple___Black_rot
# 2  Apple___Cedar_apple_rust
# 3           Apple___healthy
# 5       Blueberry___healthy
#
#                                      supplement name  \
# 0  Katyayani Prozol Propiconazole 25% EC Systemat...
# 1                    Magic FungiX For Fungal disease
# 2               Katyayani All in 1 Organic Fungicide
# 3                   Tapti Booster Organic Fertilizer
# 5                               GreenStix Fertilizer
#
#                                     supplement image  \
# 0  https://encrypted-tbn1.gstatic.com/shopping?q=...
# 1  https://encrypted-tbn3.gstatic.com/shopping?q=...
# 2  https://encrypted-tbn2.gstatic.com/shopping?q=...
# 3  https://rukminim1.flixcart.com/image/416/416/k...
# 5  https://encrypted-tbn3.gstatic.com/shopping?q=...
#
#                                             buy link  index
# 0  https://agribegri.com/products/buy-propiconazo...      0
# ...

# %% [markdown]
# ### Saving the dataset

# %%
supplement_info.to_csv('supplement_info_.csv',index=False)
