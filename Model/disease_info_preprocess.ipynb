# %% [markdown]
# ## Preporcessing the dataset
#
# * "In the dataset, there was a record that we do not require for this task, which is why we are removing it."

# %% [markdown]
# ### Loading required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading the dataset

# %%
disease_info = pd.read_csv('/content/disease_info.csv',encoding='cp1252')
disease_info.head()
# Out:
#    index               disease_name  \
# 0      0               Apple : Scab
# 1      1          Apple : Black Rot
# 2      2         Apple : Cedar rust
# 3      3            Apple : Healthy
# 4      4  Background Without Leaves
#
#                                          description  \
# 0  Apple scab is the most common disease of apple...
# 1  Leaf symptoms first occur early in the spring ...
# 2  Cedar apple rust (Gymnosporangium juniperi-vir...
# 3  As with most fruit, apples produce best when g...
# 4                There is no leaf in the given image
#
#                                       Possible Steps  \
# 0  Choose resistant varieties when possible.\nRak...
# 1  Remove the cankers by pruning at least 15 inch...
# 2  Choose resistant cultivars when available.\nRa...
# 3  Apples Are Nutritious. \nApples May Be Good fo...
# 4                    please reupload image with leaf
#
#                                            image_url
# ...

# %% [markdown]
# ### Removing the record

# %%
disease_info = disease_info.drop(disease_info[disease_info['index'] == 4].index)

# %%
disease_info.head()
# Out:
#    index         disease_name  \
# 0      0         Apple : Scab
# 1      1    Apple : Black Rot
# 2      2   Apple : Cedar rust
# 3      3      Apple : Healthy
# 5      5  Blueberry : Healthy
#
#                                          description  \
# 0  Apple scab is the most common disease of apple...
# 1  Leaf symptoms first occur early in the spring ...
# 2  Cedar apple rust (Gymnosporangium juniperi-vir...
# 3  As with most fruit, apples produce best when g...
# 5  Blueberries Are Low in Calories But High in Nu...
#
#                                       Possible Steps  \
# 0  Choose resistant varieties when possible.\nRak...
# 1  Remove the cankers by pruning at least 15 inch...
# 2  Choose resistant cultivars when available.\nRa...
# 3  Apples Are Nutritious. \nApples May Be Good fo...
# 5  Deep, low pH mulch like peat moss, pine needle...
#
#                                            image_url
# 0  https://extension.umn.edu/sites/extension.umn....
# ...

# %% [markdown]
# ### Removing the index column and adding the modified index column

# %%
disease_info.drop(columns='index',inplace=True)

# %%
disease_info['index'] = range(len(disease_info))

# %%
disease_info.head()
# Out:
#           disease_name                                        description  \
# 0         Apple : Scab  Apple scab is the most common disease of apple...
# 1    Apple : Black Rot  Leaf symptoms first occur early in the spring ...
# 2   Apple : Cedar rust  Cedar apple rust (Gymnosporangium juniperi-vir...
# 3      Apple : Healthy  As with most fruit, apples produce best when g...
# 5  Blueberry : Healthy  Blueberries Are Low in Calories But High in Nu...
#
#                                       Possible Steps  \
# 0  Choose resistant varieties when possible.\nRak...
# 1  Remove the cankers by pruning at least 15 inch...
# 2  Choose resistant cultivars when available.\nRa...
# 3  Apples Are Nutritious. \nApples May Be Good fo...
# 5  Deep, low pH mulch like peat moss, pine needle...
#
#                                            image_url  index
# 0  https://extension.umn.edu/sites/extension.umn....      0
# 1  http://www.omafra.gov.on.ca/english/crops/fact...      1
# ...

# %% [markdown]
# ### Saving the dataset

# %%
disease_info.to_csv('disease_info.csv',index=False)
